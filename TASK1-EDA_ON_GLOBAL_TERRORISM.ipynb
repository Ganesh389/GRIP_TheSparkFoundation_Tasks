# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df_terror=pd.read_csv(r"C:/Users/javadi ganesh/OneDrive/Desktop/SparkFoundation Internship/globalterrorismdb.csv",encoding='latin')
# Out:
# C:\Users\javadi ganesh\AppData\Local\Temp\ipykernel_1332\1340304081.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_terror=pd.read_csv(r"C:/Users/javadi ganesh/OneDrive/Desktop/SparkFoundation Internship/globalterrorismdb.csv",encoding='latin')

# %%
df_terror
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       1.970000e+11   1970       7     2        NaN         0        NaN
# 1       1.970000e+11   1970       0     0        NaN         0        NaN
# 2       1.970010e+11   1970       1     0        NaN         0        NaN
# 3       1.970010e+11   1970       1     0        NaN         0        NaN
# 4       1.970010e+11   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
df_terror.shape
# Out:
# (181691, 135)

# %%
df_terror.head(5)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df_terror.tail(5)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
cols=['iyear','imonth','iday','country_txt','city','latitude',
      'longitude','location','attacktype1_txt','targtype1_txt','targsubtype1_txt','target1',
      'gname','motive','weaptype1_txt','dbsource','region_txt','nkill','nwound','natlty1_txt','weapdetail'
      ]

# %%
df_terror_clean=pd.DataFrame(data=df_terror , columns=cols)

# %%
df_terror_clean.shape
# Out:
# (181691, 21)

# %%
df_terror_clean.isnull().sum()
# Out:
# iyear                    0
# imonth                   0
# iday                     0
# country_txt              0
# city                   434
# latitude              4556
# longitude             4557
# location            126196
# attacktype1_txt          0
# targtype1_txt            0
# targsubtype1_txt     10373
# target1                636
# gname                    0
# motive              131130
# weaptype1_txt            0
# dbsource                 0
# region_txt               0
# nkill                10313
# nwound               16311
# natlty1_txt           1559
# weapdetail           67670
# dtype: int64

# %%
df_terror_clean.head(2)
# Out:
#    iyear  imonth  iday         country_txt           city   latitude  \
# 0   1970       7     2  Dominican Republic  Santo Domingo  18.456792
# 1   1970       0     0              Mexico    Mexico city  19.371887
#
#    longitude location              attacktype1_txt  \
# 0 -69.951164      NaN                Assassination
# 1 -99.086624      NaN  Hostage Taking (Kidnapping)
#
#                  targtype1_txt  ...                  target1  \
# 0  Private Citizens & Property  ...             Julio Guzman
# 1      Government (Diplomatic)  ...  Nadine Chaval, daughter
#
#                                 gname motive weaptype1_txt dbsource  \
# 0                              MANO-D    NaN       Unknown     PGIS
# 1  23rd of September Communist League    NaN       Unknown     PGIS
#
#                     region_txt nkill  nwound         natlty1_txt weapdetail
# 0  Central America & Caribbean   1.0     0.0  Dominican Republic        NaN
# ...

# %%
pd.set_option("display.max_columns",500) #max coulmns

# %%
df_terror_clean.head(1)
# Out:
#    iyear  imonth  iday         country_txt           city   latitude  \
# 0   1970       7     2  Dominican Republic  Santo Domingo  18.456792
#
#    longitude location attacktype1_txt                targtype1_txt  \
# 0 -69.951164      NaN   Assassination  Private Citizens & Property
#
#   targsubtype1_txt       target1   gname motive weaptype1_txt dbsource  \
# 0   Named Civilian  Julio Guzman  MANO-D    NaN       Unknown     PGIS
#
#                     region_txt  nkill  nwound         natlty1_txt weapdetail
# 0  Central America & Caribbean    1.0     0.0  Dominican Republic        NaN

# %%
df_terror_clean['casualities']=df_terror_clean['nwound']+df_terror_clean['nkill']

# %%
df_terror_clean.head(3)
# Out:
#    iyear  imonth  iday         country_txt           city   latitude  \
# 0   1970       7     2  Dominican Republic  Santo Domingo  18.456792
# 1   1970       0     0              Mexico    Mexico city  19.371887
# 2   1970       1     0         Philippines        Unknown  15.478598
#
#     longitude location              attacktype1_txt  \
# 0  -69.951164      NaN                Assassination
# 1  -99.086624      NaN  Hostage Taking (Kidnapping)
# 2  120.599741      NaN                Assassination
#
#                  targtype1_txt  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
# 2          Journalists & Media
#
#                                     targsubtype1_txt                  target1  \
# 0                                     Named Civilian             Julio Guzman
# 1  Diplomatic Personnel (outside of embassy, cons...  Nadine Chaval, daughter
# 2                    Radio Journalist/Staff/Facility                 Employee
#
# ...

# %%
nationality_top = df_terror_clean[df_terror_clean['natlty1_txt'] != 'Unknown']

# %%
nationality_type=nationality_top['natlty1_txt'].value_counts().reset_index()

# %%
nationality_type.rename(columns={"index":'Nationality','nationality':'Counts'},inplace=True)
nationality_type
# Out:
#                         Nationality  natlty1_txt
# 0                              Iraq        24113
# 1                          Pakistan        13900
# 2                             India        12098
# 3                       Afghanistan        10931
# 4                          Colombia         7922
# ..                              ...          ...
# 210  People's Republic of the Congo            1
# 211     Saba (Netherlands Antilles)            1
# 212                          Tuvalu            1
# 213                  Western Sahara            1
# 214                Marshall Islands            1
#
# [215 rows x 2 columns]

# %%
df_terror_clean['natlty1_txt'].unique()
# Out:
# array(['Dominican Republic', 'Belgium', 'United States', 'Uruguay',
#        'Germany', 'Great Britain', 'Venezuela', 'Puerto Rico', 'Israel',
#        'Austria', 'Switzerland', 'Jordan', 'Ethiopia', 'Spain', nan,
#        'Japan', 'International', 'Egypt', 'Paraguay', 'Soviet Union',
#        'Ireland', 'Argentina', 'Philippines', 'China',
#        'West Bank and Gaza Strip', 'Multinational', 'Northern Ireland',
#        'Brazil', 'Haiti', 'South Africa', 'Portugal', 'Colombia',
#        'Greece', 'Nicaragua', 'Indonesia', 'Yugoslavia', 'Italy',
#        'Rhodesia', 'Ivory Coast', 'Iran', 'Canada', 'Poland', 'Sweden',
#        'Turkey', 'Costa Rica', 'Russia', 'Iraq', 'Cuba', 'France',
#        'Malawi', 'Democratic Republic of the Congo', 'Netherlands',
#        'Chile', 'Hong Kong', 'Yemen', 'Mexico', 'Syria', 'India',
#        'New Zealand', 'Senegal', 'Algeria', 'Peru', 'Czechoslovakia',
#        'Saudi Arabia', 'Denmark', 'West Germany (FRG)', 'Bahamas',
# ...
